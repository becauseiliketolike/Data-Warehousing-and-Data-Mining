# %% [markdown]
# # Pandas Filling out Missing Values

# %%
import pandas as pd
import numpy as np

# %%
dict_data = {
    'Field 1':[88, 90, 80 , 70],
    'Field 2': [30, 45, 50, np.nan],
    'Field 3':[np.nan, 40, 80, np.nan]
}

df_dict_data = pd.DataFrame(dict_data)
df_dict_data
# Out:
#    Field 1  Field 2  Field 3
# 0       88     30.0      NaN
# 1       90     45.0     40.0
# 2       80     50.0     80.0
# 3       70      NaN      NaN

# %%
df_dict_data.isnull()
# Out:
#    Field 1  Field 2  Field 3
# 0    False    False     True
# 1    False    False    False
# 2    False    False    False
# 3    False     True     True

# %%
df_dict_data.dropna()
# Out:
#    Field 1  Field 2  Field 3
# 1       90     45.0     40.0
# 2       80     50.0     80.0

# %%
bool_series = pd.isnull(df_dict_data["Field 3"])
bool_series
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: Field 3, dtype: bool

# %%
df_dict_data[bool_series]
# Out:
#    Field 1  Field 2  Field 3
# 0       88     30.0      NaN
# 3       70      NaN      NaN

# %% [markdown]
# ## Filling missing value with some constant (0) using fillna()

# %%
df_dict_data.fillna(23)
# Out:
#    Field 1  Field 2  Field 3
# 0       88     30.0     23.0
# 1       90     45.0     40.0
# 2       80     50.0     80.0
# 3       70     23.0     23.0

# %% [markdown]
# ## Filling a missing value with previous value

# %%
df_dict_data.fillna(method='pad', axis=1)
# Out:
#    Field 1  Field 2  Field 3
# 0     88.0     30.0     30.0
# 1     90.0     45.0     40.0
# 2     80.0     50.0     80.0
# 3     70.0     70.0     70.0

# %% [markdown]
# ## Filling a missing value with ahead value

# %%
df_dict_data.fillna(method='bfill')
# Out:
#    Field 1  Field 2  Field 3
# 0       88     30.0     40.0
# 1       90     45.0     40.0
# 2       80     50.0     80.0
# 3       70      NaN      NaN

# %% [markdown]
# # Playing with CSV

# %%
diabetes_df = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Diabetes%20Missing%20Data.csv")

# %%
diabetes_df.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
diabetes_df.isnull().sum().sum()
# Out:
# 652

# %%
diabetes_df.dropna().head()
# Out:
#     Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3          1     89.0          66.0       23.0           94.0  28.1
# 4          0    137.0          40.0       35.0          168.0  43.1
# 6          3     78.0          50.0       32.0           88.0  31.0
# 8          2    197.0          70.0       45.0          543.0  30.5
# 13         1    189.0          60.0       23.0          846.0  30.1
#
#     Diabetes_Pedigree  Age  Class
# 3               0.167   21      0
# 4               2.288   33      1
# 6               0.248   26      1
# 8               0.158   53      1
# 13              0.398   59      1

# %%
diabetes_df = diabetes_df.drop(['Serum_Insulin'], axis=1)
diabetes_df.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold   BMI  Diabetes_Pedigree  Age  \
# 0         6    148.0          72.0       35.0  33.6              0.627   50
# 1         1     85.0          66.0       29.0  26.6              0.351   31
# 2         8    183.0          64.0        NaN  23.3              0.672   32
# 3         1     89.0          66.0       23.0  28.1              0.167   21
# 4         0    137.0          40.0       35.0  43.1              2.288   33
#
#    Class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
diabetes_df["Glucose"].isnull().sum()
# Out:
# 5

# %%
diabetes_df.replace(to_replace=np.nan, value=-99).tail()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold   BMI  Diabetes_Pedigree  Age  \
# 763        10    101.0          76.0       48.0  32.9              0.171   63
# 764         2    122.0          70.0       27.0  36.8              0.340   27
# 765         5    121.0          72.0       23.0  26.2              0.245   30
# 766         1    126.0          60.0      -99.0  30.1              0.349   47
# 767         1     93.0          70.0       31.0  30.4              0.315   23
#
#      Class
# 763      0
# 764      0
# 765      0
# 766      1
# 767      0

# %%
diabetes_df[20:25]
# Out:
#     Pregnant  Glucose  Diastolic_BP  Skin_Fold   BMI  Diabetes_Pedigree  Age  \
# 20         3    126.0          88.0       41.0  39.3              0.704   27
# 21         8     99.0          84.0        NaN  35.4              0.388   50
# 22         7    196.0          90.0        NaN  39.8              0.451   41
# 23         9    119.0          80.0       35.0  29.0              0.263   29
# 24        11    143.0          94.0       33.0  36.6              0.254   51
#
#     Class
# 20      0
# 21      0
# 22      1
# 23      1
# 24      1

# %%
bool_series = pd.isnull(diabetes_df["Glucose"])

# %%
diabetes_df[bool_series]
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold   BMI  Diabetes_Pedigree  Age  \
# 75          1      NaN          48.0       20.0  24.7              0.140   22
# 182         1      NaN          74.0       20.0  27.7              0.299   21
# 342         1      NaN          68.0       35.0  32.0              0.389   22
# 349         5      NaN          80.0       32.0  41.0              0.346   37
# 502         6      NaN          68.0       41.0  39.0              0.727   41
#
#      Class
# 75       0
# 182      0
# 342      0
# 349      1
# 502      1

# %%
bool_series = pd.notnull(diabetes_df["Glucose"])

# %%
diabetes_df[bool_series].head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold   BMI  Diabetes_Pedigree  Age  \
# 0         6    148.0          72.0       35.0  33.6              0.627   50
# 1         1     85.0          66.0       29.0  26.6              0.351   31
# 2         8    183.0          64.0        NaN  23.3              0.672   32
# 3         1     89.0          66.0       23.0  28.1              0.167   21
# 4         0    137.0          40.0       35.0  43.1              2.288   33
#
#    Class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
diabetes_df["Diastolic_BP"].fillna("3", inplace=True)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP           0
# Skin_Fold            227
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %% [markdown]
# ## Filling out with missing value with Mean

# %%
diabetes_df["Glucose"].fillna(value=diabetes_df["Glucose"].mean(), inplace=True)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                0
# Diastolic_BP           0
# Skin_Fold            227
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %% [markdown]
# ## Filling out missing value with Median

# %%
diabetes_df["Skin_Fold"].fillna(value=diabetes_df["Skin_Fold"].median(), inplace=True)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnant              0
# Glucose               0
# Diastolic_BP          0
# Skin_Fold             0
# BMI                  11
# Diabetes_Pedigree     0
# Age                   0
# Class                 0
# dtype: int64

# %% [markdown]
# ## Filling out missing value with Mode

# %%
diabetes_df["BMI"].fillna(value=diabetes_df["BMI"].median(), inplace=True)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnant             0
# Glucose              0
# Diastolic_BP         0
# Skin_Fold            0
# BMI                  0
# Diabetes_Pedigree    0
# Age                  0
# Class                0
# dtype: int64

# %%
diabetes_df.corr()
# Out:
# <ipython-input-32-0aaddaacdfa9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   diabetes_df.corr()
#                    Pregnant   Glucose  Skin_Fold       BMI  Diabetes_Pedigree  \
# Pregnant           1.000000  0.127911   0.081770  0.021559          -0.033523
# Glucose            0.127911  1.000000   0.192686  0.231128           0.137060
# Skin_Fold          0.081770  0.192686   1.000000  0.543205           0.102188
# BMI                0.021559  0.231128   0.543205  1.000000           0.153438
# Diabetes_Pedigree -0.033523  0.137060   0.102188  0.153438           1.000000
# Age                0.544341  0.266534   0.126107  0.025597           0.033561
# Class              0.221898  0.492928   0.214873  0.312038           0.173844
#
#                         Age     Class
# Pregnant           0.544341  0.221898
# Glucose            0.266534  0.492928
# Skin_Fold          0.126107  0.214873
# BMI                0.025597  0.312038
# Diabetes_Pedigree  0.033561  0.173844
# Age                1.000000  0.238356
# Class              0.238356  1.000000
